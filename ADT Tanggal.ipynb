# %%
class kalender :
    def getData (self) :
        self.d = int (input ('Tanggal\t= '))
        self.m = int (input ('Bulan\t= '))
        self.y = int (input ('Tahun\t= '))
    def putData (self) :
        if self.m == 1 :
            self.hari = 31
            self.bulan= "Januari"
            
        elif self.m == 2 :
            if (self.y % 4 == 0) :
                if (self.y % 100 == 0) :
                    if (self.y % 400 == 0) :
                        self.hari = 29
                    else :
                        self.hari = 28
                else :
                    self.hari = 29
            else :
                self.hari = 28
            
            self.bulan= "Februari"
            
        elif self.m == 3 :
            self.hari = 31
            self.bulan= "Maret"
            
        elif self.m == 4 :
            self.hari = 30
            self.bulan= "April"
            
        elif self.m == 5 :
            self.hari = 31
            self.bulan= "Mei"
            
        elif self.m == 6 :
            self.hari = 30
            self.bulan= "Juni"
            
        elif self.m == 7 :
            self.hari = 31
            bulan= "Juli"
            
        elif self.m == 8 :
            self.hari = 31
            self.bulan= "Agustus"
            
        elif self.m == 9 :
            self.hari = 30
            self.bulan= "September"
            
        elif self.m == 10 :
            self.hari = 31
            self.bulan= "November"
            
        elif self.m == 11 :
            self.hari = 30
            self.bulan= "Oktober"
            
        elif self.m == 12 :
            self.hari = 31
            self.bulan= "Desember"
            
        else :
            self.hari=self.d
            self.bulan=self.m
            
    def dataDisplay (self) :
        dvalid = self.d >=1 and self.d <= self.hari
        mvalid = self.m >=1 and self.m <= 12
        valid = dvalid and mvalid
        
        if (valid) :
            print (self.d," ",self.bulan," ",self.y)
        else :
            print('invalid : Masukan kembali ! \n')
            data = kalender ()
            data.getData()
            data.putData()
            data.dataDisplay()
                
        
data = kalender ()
data.getData()
data.putData()
data.dataDisplay()
# Out:
# Tanggal	= 29
# Bulan	= 02
# Tahun	= 2000
# 29   Februari   2000

# %%
class adttanggal :
    def getdata (self) :
        self.d = int(input('masukan hari = \n'))
        self.m = int(input('masukan bulan = \n'))
        self.y = int(input('masukan tahun = \n'))
        
    def putdata (self) :
        if self.m == 1 :
            self.hari = 31
            self.bulan = "Januari"
        
        elif self.m == 2 :
            if (self.y % 4 == 0) :
                if (self.y % 100 == 0) :
                    if (self.y % 400 == 0) :
                        self.hari = 29
                    else :
                        self.hari = 28
                else :
                    self.hari = 29
            else :
                self.hari = 28
                
            self.bulan = "Februari"
        elif self.m == 3 :
            self.hari = 31
            self.bulan= "Maret"
            
        elif self.m == 4 :
            self.hari = 30
            self.bulan= "April"
            
        elif self.m == 5 :
            self.hari = 31
            self.bulan= "Mei"
            
        elif self.m == 6 :
            self.hari = 30
            self.bulan= "Juni"
            
        elif self.m == 7 :
            self.hari = 31
            bulan= "Juli"
            
        elif self.m == 8 :
            self.hari = 31
            self.bulan= "Agustus"
            
        elif self.m == 9 :
            self.hari = 30
            self.bulan= "September"
            
        elif self.m == 10 :
            self.hari = 31
            self.bulan= "November"
            
        elif self.m == 11 :
            self.hari = 30
            self.bulan= "Oktober"
            
        elif self.m == 12 :
            self.hari = 31
            self.bulan= "Desember"
            
        else :
            self.hari=self.d
            self.bulan=self.m
            
    def printdata (self) :
        dvalid = self.d >= 1 and self.d <= self.hari
        mvalid = self.m >= 1 and self.m <= 12
        valid = dvalid and mvalid
        
        if (valid) :
            print (self.d," ",self.bulan," ",self.y)
        else :
            print('invalid : Masukan kembali ! \n')
            data = adttanggal ()
            data.getdata()
            data.putdata()
            data.printdata()
            
adt = adttanggal()
adt.getdata()
adt.putdata()
adt.printdata()

# %%
class adttanggal :
    
    def getdata (self) :
        self.d = int (input ('Masukan tanggal = \n'))
        self.m = int (input ('Masukan bulan = \n'))
        self.y = int (input ('Masukan tahun = \n'))
        
    def putdata (self) :
        if self.m == 1 :
            self.hari = 31 
            self.bulan = "Januari"
            
        elif self.m == 2 :
            if (self.y % 4 == 0) :
                if (self.y % 100 == 0 ) :
                    if (self.y % 400 == 0 ) :
                        self.hari = 29
                    else :
                        self.hari = 28
                else :
                    self.hari = 29
            else :
                self.hari = 28
        elif self.m == 3 :
            self.hari = 31
            self.bulan= "Maret"
            
        elif self.m == 4 :
            self.hari = 30
            self.bulan= "April"
            
        elif self.m == 5 :
            self.hari = 31
            self.bulan= "Mei"
            
        elif self.m == 6 :
            self.hari = 30
            self.bulan= "Juni"
            
        elif self.m == 7 :
            self.hari = 31
            bulan= "Juli"
            
        elif self.m == 8 :
            self.hari = 31
            self.bulan= "Agustus"
            
        elif self.m == 9 :
            self.hari = 30
            self.bulan= "September"
            
        elif self.m == 10 :
            self.hari = 31
            self.bulan= "November"
            
        elif self.m == 11 :
            self.hari = 30
            self.bulan= "Oktober"
            
        elif self.m == 12 :
            self.hari = 31
            self.bulan= "Desember"
            
        else :
            self.hari=self.d
            self.bulan=self.m
            
    def validdata (self) :
        
        validday = self.d >=1 and self.d <= self.hari
        validmonth = self.m >=1 and self.m <= 12
        valid = validday and validmonth
        
        if (valid) :
            print (self.d," ",self.bulan," ",self.y)
        else :
            print('invalid : Masukan kembali ! \n')
            data = adttanggal ()
            data.getdata()
            data.putdata()
            data.validdata()
            
data = adttanggal()
data.getdata()
data.putdata()
data.validdata()
# Out:
# Masukan tanggal =
# 30
# Masukan bulan =
# 09
# Masukan tahun =
# 2000
# 30   September   2000
